# %%
import pandas as pd

# %%
df = pd.read_csv('./data/gemstone.csv')

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df=df.drop(labels=['id'],axis=1)

# %%
## Independent and dependent features
X = df.drop(labels=['price'],axis=1)
Y = df[['price']]

# %%
# Segregating numerical and categorical variables
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
categorical_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
numerical_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
# Define the custom ranking for each ordinal variable
cut_categories = ['Fair', 'Good', 'Very Good','Premium','Ideal']
color_categories = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
clarity_categories = ['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories])),
    ('scaler',StandardScaler())
    ]

)

preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,numerical_cols),
('cat_pipeline',cat_pipeline,categorical_cols)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['Fair',
#                                                                               'Good',
#                                                                               'Very '
#                                                                               'Good',
#                                                                               'Premium',
#                                                                               'Ideal'],
#                                                                              ['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['I1',
#                                                                               'SI2',
#                                                                               'SI1',
#                                                                               'VS2',
#                                                                               'VS1',
#                                                                               'VVS2',
#                                                                               'VVS1',
#                                                                               'IF']])),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['cut', 'color', 'clarity'], dtype='object'))])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.30, random_state=30)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train.head()
# Out:
#    num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0            -0.975439            -0.849607            -0.121531
# 1             0.235195             1.833637            -0.121531
# 2             0.494617             0.815855             0.399800
# 3            -1.018676             0.260701             0.921131
# 4            -0.953821            -0.664555            -0.642862
#
#    num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0        -1.042757        -1.080970        -1.123150           0.874076
# 1         0.318447         0.279859         0.485354          -2.144558
# 2         0.570855         0.606458         0.673737          -0.132136
# 3        -1.214034        -1.244270        -1.195605          -0.132136
# 4        -1.069801        -1.044681        -1.094168           0.874076
#
#    cat_pipeline__color  cat_pipeline__clarity
# 0             1.528722               1.352731
# 1            -0.935071              -0.646786
# 2             0.296826               0.686225
# 3             0.296826               0.019720
# 4             2.144670               1.352731

# %%
X_test.head()
# Out:
#    num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0            -0.564688            -0.942132            -0.642862
# 1            -0.175556             1.000906            -0.121531
# 2            -1.061913             0.260701            -0.121531
# 3             0.970223            -0.201927             1.963794
# 4            -0.932202            -1.312235             0.399800
#
#    num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0        -0.429765        -0.464061        -0.500036          -0.132136
# 1        -0.042137        -0.028595         0.036132          -1.138347
# 2        -1.304180        -1.298703        -1.268060           0.874076
# 3         1.048629         0.996563         0.978049          -0.132136
# 4        -1.006699        -0.990248        -1.065186          -0.132136
#
#    cat_pipeline__color  cat_pipeline__clarity
# 0            -0.935071               0.019720
# 1             0.912774              -0.646786
# 2             0.912774               2.685743
# 3             0.296826               0.019720
# 4            -0.935071               0.686225

# %%
X_train.describe()
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# count         1.355010e+05         1.355010e+05         1.355010e+05
# mean         -3.356044e-17         3.347235e-15        -1.275716e-15
# std           1.000004e+00         1.000004e+00         1.000004e+00
# min          -1.278098e+00        -8.991863e+00        -4.292180e+00
# 25%          -8.457284e-01        -4.795040e-01        -6.428619e-01
# 50%          -1.971742e-01         7.564991e-02        -1.215308e-01
# 75%           5.162355e-01         5.382781e-01         3.998003e-01
# max           5.855999e+00         9.050637e+00         6.655773e+00
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# count     1.355010e+05     1.355010e+05     1.355010e+05       1.355010e+05
# mean     -5.860492e-16    -2.340841e-16    -3.758770e-16      -5.642349e-17
# std       1.000004e+00     1.000004e+00     1.000004e+00       1.000004e+00
# min      -5.153411e+00    -5.190675e+00    -5.122673e+00      -3.150769e+00
# 25%      -9.165526e-01    -9.176705e-01    -9.202756e-01      -1.138347e+00
# 50%      -6.078784e-03    -1.378763e-03    -7.341025e-03      -1.321357e-01
# 75%       7.150886e-01     7.153247e-01     7.172103e-01       8.740755e-01
# max       3.545671e+00     3.890593e+00     4.023424e+01       8.740755e-01
#
#        cat_pipeline__color  cat_pipeline__clarity
# count         1.355010e+05           1.355010e+05
# mean          4.583098e-17           4.656511e-17
# std           1.000004e+00           1.000004e+00
# min          -1.551019e+00          -1.979798e+00
# 25%          -9.350706e-01          -6.467863e-01
# 50%           2.968257e-01           1.971957e-02
# 75%           9.127739e-01           6.862254e-01
# max           2.144670e+00           2.685743e+00

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
def model_evaluate(real,pred):
    mae=mean_absolute_error(real,pred)
    mse=mean_squared_error(real,pred)
    r2=r2_score(real,pred)
    return mae,mse,r2

# %%
models={
    "LinearRegression":LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "ElasticNet":ElasticNet()
}

# %%
trainer_model_list=[]
model_list=[]
r2_list=[]

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    Y_pred=model.predict(X_test)
    mae,mse,r2=model_evaluate(y_test,Y_pred)
    print(list(models.keys())[i])

    print("Model Performance")
    print("mean_absolute_error ",mae)
    print("mean_squared_error ",mse)
    print("r2_score ",r2)
    print("\n")
# Out:
# LinearRegression
# Model Performance
# mean_absolute_error  674.0255115796857
# mean_squared_error  1028002.7598132554
# r2_score  0.9368908248567511
#
#
# Lasso
# Model Performance
# mean_absolute_error  675.071692336216
# mean_squared_error  1027949.4559693958
# r2_score  0.9368940971841704
#
#
# Ridge
# Model Performance
# mean_absolute_error  674.0555800798198
# mean_squared_error  1028005.2293677671
# r2_score  0.9368906732505937
#
#
# ElasticNet
# Model Performance
# mean_absolute_error  1060.7368759154729
# mean_squared_error  2351365.382289642
# r2_score  0.8556494831165181
